# %%
import numpy as np

# %%
a = np.array([1,45,78,90])
b = np.diag(a) # Diagonal positions पर custom values set करता है।

print(b)
# Out:
# [[ 1  0  0  0]
#  [ 0 45  0  0]
#  [ 0  0 78  0]
#  [ 0  0  0 90]]
