# %%
print("Hello World !")
# Out:
# Hello World !

# %%
import numpy as np

# %%
a=np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
b = np.arange(1,10,4)
b
# Out:
# array([1, 5, 9])

# %%
c = np.random.randint(1,11,4)
print(c)
# Out:
# [2 9 8 9]

# %%
np.random.seed(4)
a = np.random.randint(1,10,2)
print(a)
# Out:
# [8 6]
